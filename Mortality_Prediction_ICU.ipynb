# %% [markdown]
# # Mortality Predictions in ICU using ANN (88.62%  or  ~89%)

# %%
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Handle table-like data and matrices
import numpy as np
import pandas as pd
import math 
# Modelling Algorithms
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier , GradientBoostingClassifier
from sklearn.metrics import accuracy_score

# Modelling Helpers
from sklearn.preprocessing import Imputer , Normalizer , scale
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFECV

import keras
from keras import backend as K

# Visualisation
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

# Configure visualisations
# %matplotlib inline
mpl.style.use( 'ggplot' )
sns.set_style( 'white' )
pylab.rcParams[ 'figure.figsize' ] = 8 , 6
# Out:
# Using TensorFlow backend.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3c2b7b77-fdbc-4d98-a33e-493cc4328730" name="files[]" multiple disabled />
#      <output id="result-3c2b7b77-fdbc-4d98-a33e-493cc4328730">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train.csv

# %%
import pandas as pd
import io
df = pd.read_csv(io.StringIO(uploaded['train.csv'].decode('utf-8')))

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-45107592-e901-46b4-b4fc-7fb098cf1073" name="files[]" multiple disabled />
#      <output id="result-45107592-e901-46b4-b4fc-7fb098cf1073">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving labels.csv to labels.csv

# %%
import pandas as pd
import io
labels = pd.read_csv(io.StringIO(uploaded['labels.csv'].decode('utf-8')))

# %%
df.head()
# Out:
#      ALP   ALT    AST  Age   Albumin        BUN  Bilirubin  Cholesterol  \
# 0   77.0  31.0   46.0   54  2.973333  10.500000        0.7        154.0
# 1   77.0  31.0   46.0   76  2.973333  18.333333        0.7        154.0
# 2  116.0  83.0  199.5   44  2.500000   4.666667        2.9        154.0
# 3  105.0  12.0   15.0   68  4.400000  17.666667        0.2        154.0
# 4   77.0  31.0   46.0   88  3.300000  35.000000        0.7        154.0
#
#    Creatinine    DiasABP    ...      RespRate       SaO2      SysABP  \
# 0    0.750000  58.795833    ...     17.428571  97.250000  116.891892
# 1    1.100000  58.897059    ...     19.000000  96.833333  113.411765
# 2    0.333333  67.125000    ...     19.000000  95.000000  125.687500
# 3    0.766667  58.795833    ...     15.457627  97.250000  116.891892
# 4    1.000000  58.795833    ...     19.166667  97.250000  116.891892
#
#         Temp  TroponinI  TroponinT       Urine        WBC     Weight        pH
# 0  37.357143        2.1       0.14  171.052632  10.300000  80.060976  7.387273
# 1  36.939130        2.1       0.14  151.560976  11.266667  80.670588  7.395000
# 2  37.800000        2.1       0.14  124.951220   4.700000  56.700000  7.495000
# 3  36.223077        2.1       0.14  545.833333   9.400000  84.600000  7.387273
# 4  36.880000        2.1       0.14   62.131579   4.300000  80.060976  7.387273
#
# [5 rows x 42 columns]

# %%
df.columns
# Out:
# Index(['ALP', 'ALT', 'AST', 'Age', 'Albumin', 'BUN', 'Bilirubin',
#        'Cholesterol', 'Creatinine', 'DiasABP', 'FiO2', 'GCS', 'Gender',
#        'Glucose', 'HCO3', 'HCT', 'HR', 'Height', 'ICUType', 'K', 'Lactate',
#        'MAP', 'MechVent', 'Mg', 'NIDiasABP', 'NIMAP', 'NISysABP', 'Na',
#        'PaCO2', 'PaO2', 'Platelets', 'RecordID', 'RespRate', 'SaO2', 'SysABP',
#        'Temp', 'TroponinI', 'TroponinT', 'Urine', 'WBC', 'Weight', 'pH'],
#       dtype='object')

# %%
df.shape
# Out:
# (3999, 42)

# %%
df.describe()
# Out:
#                ALP          ALT           AST          Age      Albumin  \
# count  3999.000000  3999.000000   3999.000000  3999.000000  3999.000000
# mean     89.259978    91.709903    130.219258    64.247562     2.975942
# std      70.397850   427.290858    590.482153    17.563142     0.404440
# min      12.000000     3.000000      6.000000    15.000000     1.100000
# 25%      77.000000    31.000000     46.000000    52.500000     2.973333
# 50%      77.000000    31.000000     46.000000    67.000000     2.973333
# 75%      82.000000    32.250000     49.000000    78.000000     3.000000
# max    1472.333333  9143.428571  15680.000000    90.000000     5.300000
#
#                BUN    Bilirubin  Cholesterol   Creatinine      DiasABP  \
# count  3999.000000  3999.000000  3999.000000  3999.000000  3999.000000
# mean     25.449665     1.216527   152.403601     1.363130    59.262693
# std      20.586576     2.961385    13.891279     1.406947     9.080069
# min       2.250000     0.100000     0.000000     0.200000     0.000000
# 25%      13.000000     0.700000   154.000000     0.700000    55.843712
# 50%      19.000000     0.700000   154.000000     0.933333    58.795833
# 75%      30.000000     0.700000   154.000000     1.366667    62.210006
# max     170.833333    46.366667   330.000000    16.457143   106.666667
#
#           ...          RespRate         SaO2       SysABP         Temp  \
# count     ...       3999.000000  3999.000000  3999.000000  3999.000000
# mean      ...         19.223967    96.940907   118.145550    36.956291
# std       ...          2.074830     2.296143    16.540816     0.727382
# min       ...         10.543478    38.800000     0.000000    21.644615
# 25%       ...         19.000000    97.230769   111.099359    36.614286
# 50%       ...         19.000000    97.250000   116.891892    36.968750
# 75%       ...         19.290323    97.250000   123.504098    37.364401
# max       ...         39.655172   100.000000   181.725000    39.748980
#
#          TroponinI    TroponinT        Urine          WBC       Weight  \
# count  3999.000000  3999.000000  3999.000000  3999.000000  3999.000000
# mean      2.368702     0.337362   133.363074    12.521058    82.799384
# std       2.418656     1.276145   117.304284     6.466063    23.117431
# min       0.300000     0.010000     0.000000     0.100000     3.500000
# 25%       2.100000     0.125000    74.044118     8.900000    68.201064
# 50%       2.100000     0.140000   111.032258    11.466667    80.060976
# 75%       2.100000     0.140000   160.419207    14.950000    93.040476
# max      49.200000    24.040000  3082.380952   137.233333   300.000000
#
#                 pH
# count  3999.000000
# mean      7.488870
# std       2.986373
# min       6.311667
# 25%       7.364142
# 50%       7.387273
# 75%       7.407500
# max     128.532500
#
# [8 rows x 42 columns]

# %%
labels["In-hospital_death"].value_counts()
# Out:
# 0    3445
# 1     554
# Name: In-hospital_death, dtype: int64

# %%
labels.shape
# Out:
# (3999, 1)

# %% [markdown]
# **One hot encoding**

# %%
temp  =[]
for i in labels["In-hospital_death"]:
  if i == 0:
    temp.append([1,0])
  else:
    temp.append([0,1])
temp = np.array(temp)

# %%
print(temp.shape)
# Out:
# (3999, 2)

# %%
new = pd.concat([df , labels] , axis = 1)
print(new.shape)
# Out:
# (3999, 43)

# %% [markdown]
# **Using correlation heatmap to find important features and their relations with other features.**

# %% [markdown]
# ### Remember , "correlation is not causation".

# %%
correlation_map = new[new.columns].corr()
obj = np.array(correlation_map)
obj[np.tril_indices_from(obj)] = False
fig,ax= plt.subplots()
fig.set_size_inches(35,28)
sns.heatmap(correlation_map, mask=obj,vmax=.7, square=True,annot=True)

# %%
new_df = new.drop(['In-hospital_death'] , axis =1)
new_df.shape
# Out:
# (3999, 42)

# %%
df = new_df

# %% [markdown]
# ### After repeated feature selection , the below were the best set of features to be dropped to get the best model performance.

# %% [markdown]
# ### Best feature selection is done on the basis of intuition and context.

# %%
df = df.drop(['Gender','Cholesterol','HCT','ICUType','Height'] , axis =1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
df = scaler.fit_transform(df)

# %%
X = df
y = temp

# %%
print(X.shape , y.shape)
# Out:
# (3999, 37) (3999, 2)

# %%
X_train , X_test , y_train , y_test  = train_test_split(X , y , test_size = 0.2)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (3199, 37) (800, 37) (3199, 2) (800, 2)

# %%
filepath="icu_weights.hdf5"
from keras.callbacks import ReduceLROnPlateau , ModelCheckpoint

lr_reduce = ReduceLROnPlateau(monitor='val_acc', factor=0.1, epsilon=0.0001, patience=1, verbose=1)
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %% [markdown]
# ### Checkpointing the model weights and saving prior to overfitting.

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout , BatchNormalization
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.optimizers import RMSprop, Adam

# %% [markdown]
# ## This is the best model that I can come up with and has a validation accuracy of 88.62 %.

# %% [markdown]
# ### After repeatedly tuning the model architecture and other hyperparameters , finally a layer of BatchNormalization did some good to accuracy when added to correct place in the architecture.

# %%
model = Sequential()

model.add(Dense(64, input_dim=X_train.shape[1] , activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(196, activation='relu'))
model.add(Dense(196, activation='relu'))

model.add(BatchNormalization())

model.add(Dense(256, activation='relu'))
model.add(Dense(2, activation='sigmoid'))

model.compile(optimizer = Adam(lr = 0.0005),loss='binary_crossentropy', metrics=['accuracy'])
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_299 (Dense)            (None, 64)                2432
# _________________________________________________________________
# dense_300 (Dense)            (None, 128)               8320
# _________________________________________________________________
# dense_301 (Dense)            (None, 196)               25284
# _________________________________________________________________
# dense_302 (Dense)            (None, 196)               38612
# _________________________________________________________________
# batch_normalization_60 (Batc (None, 196)               784
# _________________________________________________________________
# dense_303 (Dense)            (None, 256)               50432
# _________________________________________________________________
# dense_304 (Dense)            (None, 2)                 514
# =================================================================
# Total params: 126,378
# Trainable params: 125,986
# Non-trainable params: 392
# _________________________________________________________________
# None

# %%
history = model.fit(X_train, y_train , epochs=15 , batch_size = 128 , validation_data=(X_test, y_test) , callbacks=[checkpoint,lr_reduce])
# Out:
# Train on 3199 samples, validate on 800 samples
# Epoch 1/15
# 3199/3199 [==============================] - 6s 2ms/step - loss: 0.4451 - acc: 0.8303 - val_loss: 0.3235 - val_acc: 0.8700
#
# Epoch 00001: val_acc did not improve from 0.88375
# Epoch 2/15
# 3199/3199 [==============================] - 0s 100us/step - loss: 0.3502 - acc: 0.8621 - val_loss: 0.3045 - val_acc: 0.8756
#
# Epoch 00002: val_acc did not improve from 0.88375
# Epoch 3/15
# 3199/3199 [==============================] - 0s 99us/step - loss: 0.3364 - acc: 0.8656 - val_loss: 0.3149 - val_acc: 0.8775
#
# Epoch 00003: val_acc did not improve from 0.88375
# Epoch 4/15
# 3199/3199 [==============================] - 0s 104us/step - loss: 0.3253 - acc: 0.8704 - val_loss: 0.3215 - val_acc: 0.8706
#
# Epoch 00004: val_acc did not improve from 0.88375
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 5.0000002374872565e-05.
# Epoch 5/15
# 3199/3199 [==============================] - 0s 99us/step - loss: 0.3152 - acc: 0.8745 - val_loss: 0.3006 - val_acc: 0.8756
#
# Epoch 00005: val_acc did not improve from 0.88375
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 5.000000237487257e-06.
# Epoch 6/15
# 3199/3199 [==============================] - 0s 97us/step - loss: 0.3115 - acc: 0.8748 - val_loss: 0.2956 - val_acc: 0.8794
#
# Epoch 00006: val_acc did not improve from 0.88375
# Epoch 7/15
# 3199/3199 [==============================] - 0s 101us/step - loss: 0.3111 - acc: 0.8753 - val_loss: 0.2935 - val_acc: 0.8794
#
# Epoch 00007: val_acc did not improve from 0.88375
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 5.000000328436726e-07.
# Epoch 8/15
# 3199/3199 [==============================] - 0s 98us/step - loss: 0.3090 - acc: 0.8753 - val_loss: 0.2927 - val_acc: 0.8825
#
# Epoch 00008: val_acc did not improve from 0.88375
# Epoch 9/15
# 3199/3199 [==============================] - 0s 100us/step - loss: 0.3107 - acc: 0.8764 - val_loss: 0.2924 - val_acc: 0.8825
#
# Epoch 00009: val_acc did not improve from 0.88375
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 5.000000555810402e-08.
# Epoch 10/15
# 3199/3199 [==============================] - 0s 101us/step - loss: 0.3106 - acc: 0.8740 - val_loss: 0.2924 - val_acc: 0.8850
#
# Epoch 00010: val_acc improved from 0.88375 to 0.88500, saving model to icu_weights.hdf5
# Epoch 11/15
# 3199/3199 [==============================] - 0s 100us/step - loss: 0.3098 - acc: 0.8762 - val_loss: 0.2925 - val_acc: 0.8856
#
# Epoch 00011: val_acc improved from 0.88500 to 0.88562, saving model to icu_weights.hdf5
# Epoch 12/15
#  128/3199 [>.............................] - ETA: 0s - loss: 0.3391 - acc: 0.86723199/3199 [==============================] - 0s 100us/step - loss: 0.3101 - acc: 0.8750 - val_loss: 0.2926 - val_acc: 0.8862
#
# Epoch 00012: val_acc improved from 0.88562 to 0.88625, saving model to icu_weights.hdf5
# Epoch 13/15
# 3199/3199 [==============================] - 0s 99us/step - loss: 0.3095 - acc: 0.8768 - val_loss: 0.2927 - val_acc: 0.8862
#
# Epoch 00013: val_acc did not improve from 0.88625
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-09.
# Epoch 14/15
# 3199/3199 [==============================] - 0s 98us/step - loss: 0.3104 - acc: 0.8757 - val_loss: 0.2928 - val_acc: 0.8862
#
# Epoch 00014: val_acc did not improve from 0.88625
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-10.
# Epoch 15/15
# 3199/3199 [==============================] - 0s 99us/step - loss: 0.3095 - acc: 0.8762 - val_loss: 0.2929 - val_acc: 0.8850
#
# Epoch 00015: val_acc did not improve from 0.88625
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-11.

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ** 0 - Survival in hospital ,
#    1 - Death in hospital.**

# %% [markdown]
# **Also are survivial and deaths are not equal , so we can't use validation accuracy as the soul criterion for calculating model performance.**

# %% [markdown]
# ### Here, precision is more significant than recall (particularly for this dataset). This is due to the fact and the area of context in which the problem lies.

# %% [markdown]
# ### The context is ......

# %% [markdown]
# ### In the above problem, lets say for one time the model can predict a person in ICU who would be dead in coming future as alive

# %% [markdown]
# ## BUT

# %% [markdown]
# ### A model must not predict a person in ICU who would stay alive in coming future as dead.

# %% [markdown]
# #### Just try to read the above lines more and more to get the real essense of those lines above.
# #### Therefore, this leads to minimize the false positives in the above example which gives higher precision. (positive is for deaths as stated above)

# %%
from sklearn.metrics import confusion_matrix
pred = model.predict(X_test)
pred = np.argmax(pred,axis = 1) 
y_true = np.argmax(y_test,axis = 1)

# %% [markdown]
# ### The precision for the model is approx 80% and the validation accuracy is approx. 89%.

# %%
cnf_matrix = confusion_matrix(y_true, pred)
print(cnf_matrix)
# Out:
# [[688   6]
#  [ 84  22]]
